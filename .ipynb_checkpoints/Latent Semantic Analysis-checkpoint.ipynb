# %%
import csv
import pandas as pd
import numpy as np

import os.path
from gensim import corpora
from gensim.models import LsiModel
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

# %%
file_name2 = "scopus.csv"
df_scopus = pd.read_csv(file_name2)
df_scopus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Authors                        836 non-null    object
#  1   Author(s) ID                   835 non-null    object
#  2   Title                          836 non-null    object
#  3   Year                           836 non-null    int64
#  4   Source title                   836 non-null    object
#  5   Volume                         823 non-null    object
#  6   Issue                          759 non-null    object
#  7   Art. No.                       137 non-null    object
#  8   Page start                     713 non-null    object
#  9   Page end                       713 non-null    object
#  10  Page count                     1 non-null      float64
#  11  Cited by                       667 non-null    float64
#  12  DOI                            734 non-null    object
#  13  Link                           836 non-null    object
#  14  Affiliations                   817 non-null    object
#  15  Authors with affiliations      834 non-null    object
#  16  Abstract                       836 non-null    object
#  17  Author Keywords                723 non-null    object
#  18  Index Keywords                 210 non-null    object
#  19  Molecular Sequence Numbers     0 non-null      float64
#  20  Chemicals/CAS                  0 non-null      float64
#  21  Tradenames                     0 non-null      float64
#  22  Manufacturers                  0 non-null      float64
#  23  Funding Details                177 non-null    object
#  24  Funding Text 1                 211 non-null    object
#  25  Funding Text 2                 46 non-null     object
#  26  Funding Text 3                 3 non-null      object
#  27  Funding Text 4                 1 non-null      object
#  28  Funding Text 5                 0 non-null      float64
#  29  Funding Text 6                 0 non-null      float64
#  30  Funding Text 7                 0 non-null      float64
#  31  Funding Text 8                 0 non-null      float64
#  32  Funding Text 9                 0 non-null      float64
#  33  Funding Text 10                0 non-null      float64
#  34  References                     830 non-null    object
#  35  Correspondence Address         730 non-null    object
#  36  Editors                        0 non-null      float64
#  37  Sponsors                       0 non-null      float64
#  38  Publisher                      637 non-null    object
#  39  Conference name                0 non-null      float64
#  40  Conference date                0 non-null      float64
#  41  Conference location            0 non-null      float64
#  42  Conference code                0 non-null      float64
#  43  ISSN                           836 non-null    object
#  44  ISBN                           0 non-null      float64
#  45  CODEN                          62 non-null     object
#  46  PubMed ID                      83 non-null     float64
#  47  Language of Original Document  836 non-null    object
#  48  Abbreviated Source Title       836 non-null    object
#  49  Document Type                  836 non-null    object
#  50  Publication Stage              836 non-null    object
#  51  Open Access                    352 non-null    object
#  52  Source                         836 non-null    object
#  53  EID                            836 non-null    object
# dtypes: float64(20), int64(1), object(33)
# memory usage: 352.8+ KB

# %%
relevant_columns = {"index": "DOI", "LSA": "Title  Abstract  Author Keywords  Index Keywords".split("  ")}

# %%
df_docs = df_scopus[["DOI"]+relevant_columns["LSA"]]
df_docs = df_docs.set_index("DOI")
df_docs["Abstract"] = df_docs["Abstract"].replace({"[No abstract available]": np.nan})
df_docs = df_docs.fillna("")
df_docs
# Out:
#                                                                             Title  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Students’ learning sustainability – implicit, ...
# 10.1057/s41599-022-01129-0      Going beyond the AHA! moment: insight discover...
# 10.1186/s12909-022-03308-8      An online Delphi study to investigate the comp...
# 10.1186/s12909-022-03283-0      How do medical students learn conceptual knowl...
# 10.1186/s12909-022-03259-0      How medical students co-regulate their learnin...
# ...                                                                           ...
# 10.1080/0305569930190108        Professional Development and Competence-based ...
# NaN                             Key competencies for receiving or making your ...
# 10.1080/0309877920160311        “Quality Management’ or “The Educative Workpla...
# 10.1016/0261-5177(92)90051-8    The implications of competence based education...
# 10.1080/00048623.1992.10754796           Information Literacy — A Core Competency
#
#                                                                          Abstract  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Purpose: This study aims to understand better ...
# 10.1057/s41599-022-01129-0      In this paper, we develop and apply the concep...
# 10.1186/s12909-022-03308-8      Background: Several competency frameworks are ...
# 10.1186/s12909-022-03283-0      Background: Acquiring medical knowledge is a k...
# 10.1186/s12909-022-03259-0      Background: Self-regulated learning is a key c...
# ...                                                                           ...
# 10.1080/0305569930190108        The rapid expansion of competence-based educat...
# NaN
# 10.1080/0309877920160311        Competence-based education has been the topic ...
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796  The Finn Report highlights the need for young ...
#
#                                                                   Author Keywords  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Higher education institutions (HEIs); Sustaina...
# 10.1057/s41599-022-01129-0
# 10.1186/s12909-022-03308-8      Allied health disciplines; CanMEDS; Continuous...
# 10.1186/s12909-022-03283-0      Learning difficulties; Learning techniques; Me...
# 10.1186/s12909-022-03259-0      Clinical clerkships; Co-regulated learning; Me...
# ...                                                                           ...
# 10.1080/0305569930190108
# NaN
# 10.1080/0309877920160311
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796
#
#                                                                    Index Keywords
# DOI
# 10.1108/IJSHE-12-2020-0484
# 10.1057/s41599-022-01129-0
# 10.1186/s12909-022-03308-8      article; audiology; Belgium; clinical article;...
# 10.1186/s12909-022-03283-0      adult; article; controlled study; curriculum; ...
# 10.1186/s12909-022-03259-0      clinical education; human; learning; medical e...
# ...                                                                           ...
# 10.1080/0305569930190108
# NaN
# 10.1080/0309877920160311
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796
#
# [836 rows x 4 columns]

# %%
df_docs["doc"] = df_docs.apply(lambda x: ". ".join(x.values), axis=1)
df_docs
# Out:
#                                                                             Title  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Students’ learning sustainability – implicit, ...
# 10.1057/s41599-022-01129-0      Going beyond the AHA! moment: insight discover...
# 10.1186/s12909-022-03308-8      An online Delphi study to investigate the comp...
# 10.1186/s12909-022-03283-0      How do medical students learn conceptual knowl...
# 10.1186/s12909-022-03259-0      How medical students co-regulate their learnin...
# ...                                                                           ...
# 10.1080/0305569930190108        Professional Development and Competence-based ...
# NaN                             Key competencies for receiving or making your ...
# 10.1080/0309877920160311        “Quality Management’ or “The Educative Workpla...
# 10.1016/0261-5177(92)90051-8    The implications of competence based education...
# 10.1080/00048623.1992.10754796           Information Literacy — A Core Competency
#
#                                                                          Abstract  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Purpose: This study aims to understand better ...
# 10.1057/s41599-022-01129-0      In this paper, we develop and apply the concep...
# 10.1186/s12909-022-03308-8      Background: Several competency frameworks are ...
# 10.1186/s12909-022-03283-0      Background: Acquiring medical knowledge is a k...
# 10.1186/s12909-022-03259-0      Background: Self-regulated learning is a key c...
# ...                                                                           ...
# 10.1080/0305569930190108        The rapid expansion of competence-based educat...
# NaN
# 10.1080/0309877920160311        Competence-based education has been the topic ...
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796  The Finn Report highlights the need for young ...
#
#                                                                   Author Keywords  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Higher education institutions (HEIs); Sustaina...
# 10.1057/s41599-022-01129-0
# 10.1186/s12909-022-03308-8      Allied health disciplines; CanMEDS; Continuous...
# 10.1186/s12909-022-03283-0      Learning difficulties; Learning techniques; Me...
# 10.1186/s12909-022-03259-0      Clinical clerkships; Co-regulated learning; Me...
# ...                                                                           ...
# 10.1080/0305569930190108
# NaN
# 10.1080/0309877920160311
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796
#
#                                                                    Index Keywords  \
# DOI
# 10.1108/IJSHE-12-2020-0484
# 10.1057/s41599-022-01129-0
# 10.1186/s12909-022-03308-8      article; audiology; Belgium; clinical article;...
# 10.1186/s12909-022-03283-0      adult; article; controlled study; curriculum; ...
# 10.1186/s12909-022-03259-0      clinical education; human; learning; medical e...
# ...                                                                           ...
# 10.1080/0305569930190108
# NaN
# 10.1080/0309877920160311
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796
#
#                                                                               doc
# DOI
# 10.1108/IJSHE-12-2020-0484      Students’ learning sustainability – implicit, ...
# 10.1057/s41599-022-01129-0      Going beyond the AHA! moment: insight discover...
# 10.1186/s12909-022-03308-8      An online Delphi study to investigate the comp...
# 10.1186/s12909-022-03283-0      How do medical students learn conceptual knowl...
# 10.1186/s12909-022-03259-0      How medical students co-regulate their learnin...
# ...                                                                           ...
# 10.1080/0305569930190108        Professional Development and Competence-based ...
# NaN                             Key competencies for receiving or making your ...
# 10.1080/0309877920160311        “Quality Management’ or “The Educative Workpla...
# 10.1016/0261-5177(92)90051-8    The implications of competence based education...
# 10.1080/00048623.1992.10754796  Information Literacy — A Core Competency. The ...
#
# [836 rows x 5 columns]

# %%
from gensim.parsing.preprocessing import remove_stopwords, strip_punctuation, preprocess_string, strip_short, stem_text

# %%
def preprocess(text):
    CUSTOM_FILTERS = [lambda x: x.lower(), 
                                remove_stopwords, 
                                strip_punctuation, 
                                strip_short, 
                                stem_text]
    text = preprocess_string(text, CUSTOM_FILTERS)
    return text

# %%
df_docs['doc_clean'] = df_docs['doc'].apply(lambda x: preprocess(x))

# %%
df_docs
# Out:
#                                                                             Title  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Students’ learning sustainability – implicit, ...
# 10.1057/s41599-022-01129-0      Going beyond the AHA! moment: insight discover...
# 10.1186/s12909-022-03308-8      An online Delphi study to investigate the comp...
# 10.1186/s12909-022-03283-0      How do medical students learn conceptual knowl...
# 10.1186/s12909-022-03259-0      How medical students co-regulate their learnin...
# ...                                                                           ...
# 10.1080/0305569930190108        Professional Development and Competence-based ...
# NaN                             Key competencies for receiving or making your ...
# 10.1080/0309877920160311        “Quality Management’ or “The Educative Workpla...
# 10.1016/0261-5177(92)90051-8    The implications of competence based education...
# 10.1080/00048623.1992.10754796           Information Literacy — A Core Competency
#
#                                                                          Abstract  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Purpose: This study aims to understand better ...
# 10.1057/s41599-022-01129-0      In this paper, we develop and apply the concep...
# 10.1186/s12909-022-03308-8      Background: Several competency frameworks are ...
# 10.1186/s12909-022-03283-0      Background: Acquiring medical knowledge is a k...
# 10.1186/s12909-022-03259-0      Background: Self-regulated learning is a key c...
# ...                                                                           ...
# 10.1080/0305569930190108        The rapid expansion of competence-based educat...
# NaN
# 10.1080/0309877920160311        Competence-based education has been the topic ...
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796  The Finn Report highlights the need for young ...
#
#                                                                   Author Keywords  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Higher education institutions (HEIs); Sustaina...
# 10.1057/s41599-022-01129-0
# 10.1186/s12909-022-03308-8      Allied health disciplines; CanMEDS; Continuous...
# 10.1186/s12909-022-03283-0      Learning difficulties; Learning techniques; Me...
# 10.1186/s12909-022-03259-0      Clinical clerkships; Co-regulated learning; Me...
# ...                                                                           ...
# 10.1080/0305569930190108
# NaN
# 10.1080/0309877920160311
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796
#
#                                                                    Index Keywords  \
# DOI
# 10.1108/IJSHE-12-2020-0484
# 10.1057/s41599-022-01129-0
# 10.1186/s12909-022-03308-8      article; audiology; Belgium; clinical article;...
# 10.1186/s12909-022-03283-0      adult; article; controlled study; curriculum; ...
# 10.1186/s12909-022-03259-0      clinical education; human; learning; medical e...
# ...                                                                           ...
# 10.1080/0305569930190108
# NaN
# 10.1080/0309877920160311
# 10.1016/0261-5177(92)90051-8
# 10.1080/00048623.1992.10754796
#
#                                                                               doc  \
# DOI
# 10.1108/IJSHE-12-2020-0484      Students’ learning sustainability – implicit, ...
# 10.1057/s41599-022-01129-0      Going beyond the AHA! moment: insight discover...
# 10.1186/s12909-022-03308-8      An online Delphi study to investigate the comp...
# 10.1186/s12909-022-03283-0      How do medical students learn conceptual knowl...
# 10.1186/s12909-022-03259-0      How medical students co-regulate their learnin...
# ...                                                                           ...
# 10.1080/0305569930190108        Professional Development and Competence-based ...
# NaN                             Key competencies for receiving or making your ...
# 10.1080/0309877920160311        “Quality Management’ or “The Educative Workpla...
# 10.1016/0261-5177(92)90051-8    The implications of competence based education...
# 10.1080/00048623.1992.10754796  Information Literacy — A Core Competency. The ...
#
#                                                                         doc_clean
# DOI
# 10.1108/IJSHE-12-2020-0484      [students’, learn, sustain, implicit, explicit...
# 10.1057/s41599-022-01129-0      [go, aha, moment, insight, discoveri, transdis...
# 10.1186/s12909-022-03308-8      [onlin, delphi, studi, investig, complet, canm...
# 10.1186/s12909-022-03283-0      [medic, student, learn, conceptu, knowledg, hi...
# 10.1186/s12909-022-03259-0      [medic, student, regul, learn, clinic, clerksh...
# ...                                                                           ...
# 10.1080/0305569930190108        [profession, develop, compet, base, educ, rapi...
# NaN                             [kei, compet, receiv, make, histori, issu, ari...
# 10.1080/0309877920160311        [“qualiti, management’, “the, educ, workplace’...
# 10.1016/0261-5177(92)90051-8    [implic, compet, base, educ, train, programm, ...
# 10.1080/00048623.1992.10754796  [inform, literaci, core, compet, finn, report,...
#
# [836 rows x 6 columns]

# %%
import json
  
f = open('citation_net.json', encoding='utf-8-sig')
data = json.load(f)
network = data["network"]

# %%
network_items = pd.DataFrame(network["items"])
network_items["DOI"] = network_items["url"].apply(lambda x: x.replace("https://doi.org/", "") if str(x) != "nan" else np.nan)
network_items = network_items.set_index("DOI")

# %%
network_items
# Out:
#                                      id                   label  \
# DOI
# 10.1108/ijshe-12-2020-0484            1           alm k. (2022)
# 10.1057/s41599-022-01047-1            7    škrinjarić b. (2022)
# 10.14201/teri.25394                  10        leal m.s. (2022)
# 10.3390/su14094916                   11          venn r. (2022)
# 10.1108/et-11-2020-0341              12  van der baan n. (2022)
# ...                                 ...                     ...
# 10.1080/0305569980240309            810        hyland t. (1998)
# 10.1111/1467-9752.00070             814        hyland t. (1997)
# 10.1111/j.1467-9752.1996.tb00406.x  818       bridges d. (1996)
# 10.1080/0305569940200208            829       hyland t. (1994b)
# 10.1007/bf01383845                  831  everwijn s.e.m. (1993)
#
#                                                                           description  \
# DOI
# 10.1108/ijshe-12-2020-0484          <table><tr><td>Authors:</td><td>alm k.; beery ...
# 10.1057/s41599-022-01047-1          <table><tr><td>Authors:</td><td>škrinjarić b.<...
# 10.14201/teri.25394                 <table><tr><td>Authors:</td><td>leal m.s.; góm...
# 10.3390/su14094916                  <table><tr><td>Authors:</td><td>venn r.; perez...
# 10.1108/et-11-2020-0341             <table><tr><td>Authors:</td><td>van der baan n...
# ...                                                                               ...
# 10.1080/0305569980240309            <table><tr><td>Authors:</td><td>hyland t.</td>...
# 10.1111/1467-9752.00070             <table><tr><td>Authors:</td><td>hyland t.</td>...
# 10.1111/j.1467-9752.1996.tb00406.x  <table><tr><td>Authors:</td><td>bridges d.</td...
# 10.1080/0305569940200208            <table><tr><td>Authors:</td><td>hyland t.</td>...
# 10.1007/bf01383845                  <table><tr><td>Authors:</td><td>everwijn s.e.m...
#
#                                                                                   url  \
# DOI
# 10.1108/ijshe-12-2020-0484                 https://doi.org/10.1108/ijshe-12-2020-0484
# 10.1057/s41599-022-01047-1                 https://doi.org/10.1057/s41599-022-01047-1
# 10.14201/teri.25394                               https://doi.org/10.14201/teri.25394
# 10.3390/su14094916                                 https://doi.org/10.3390/su14094916
# 10.1108/et-11-2020-0341                       https://doi.org/10.1108/et-11-2020-0341
# ...                                                                               ...
# 10.1080/0305569980240309                     https://doi.org/10.1080/0305569980240309
# 10.1111/1467-9752.00070                       https://doi.org/10.1111/1467-9752.00070
# 10.1111/j.1467-9752.1996.tb00406.x  https://doi.org/10.1111/j.1467-9752.1996.tb004...
# 10.1080/0305569940200208                     https://doi.org/10.1080/0305569940200208
# 10.1007/bf01383845                                 https://doi.org/10.1007/bf01383845
#
#                                          x       y  cluster  \
# DOI
# 10.1108/ijshe-12-2020-0484          0.9303  0.0346        1
# 10.1057/s41599-022-01047-1          0.5354  0.1785        7
# 10.14201/teri.25394                -0.4185  0.3001        3
# 10.3390/su14094916                  0.6689 -0.1122        1
# 10.1108/et-11-2020-0341            -0.2235 -0.1336        4
# ...                                    ...     ...      ...
# 10.1080/0305569980240309            1.3659 -0.2596        8
# 10.1111/1467-9752.00070             1.2536 -0.2308        8
# 10.1111/j.1467-9752.1996.tb00406.x  0.3718  0.0827        7
# 10.1080/0305569940200208            1.4045 -0.2693        8
# 10.1007/bf01383845                 -0.7127 -0.1921        4
#
#                                                                               weights  \
# DOI
# 10.1108/ijshe-12-2020-0484          {'Links': 4.0, 'Citations': 1.0, 'Norm. citati...
# 10.1057/s41599-022-01047-1          {'Links': 5.0, 'Citations': 0.0, 'Norm. citati...
# 10.14201/teri.25394                 {'Links': 1.0, 'Citations': 0.0, 'Norm. citati...
# 10.3390/su14094916                  {'Links': 6.0, 'Citations': 0.0, 'Norm. citati...
# 10.1108/et-11-2020-0341             {'Links': 2.0, 'Citations': 0.0, 'Norm. citati...
# ...                                                                               ...
# 10.1080/0305569980240309            {'Links': 2.0, 'Citations': 10.0, 'Norm. citat...
# 10.1111/1467-9752.00070             {'Links': 2.0, 'Citations': 55.0, 'Norm. citat...
# 10.1111/j.1467-9752.1996.tb00406.x  {'Links': 1.0, 'Citations': 18.0, 'Norm. citat...
# 10.1080/0305569940200208            {'Links': 1.0, 'Citations': 6.0, 'Norm. citati...
# 10.1007/bf01383845                  {'Links': 1.0, 'Citations': 24.0, 'Norm. citat...
#
#                                                                                scores
# DOI
# 10.1108/ijshe-12-2020-0484          {'Pub. year': 2022.0, 'Citations': 1.0, 'Norm....
# 10.1057/s41599-022-01047-1          {'Pub. year': 2022.0, 'Citations': 0.0, 'Norm....
# 10.14201/teri.25394                 {'Pub. year': 2022.0, 'Citations': 0.0, 'Norm....
# 10.3390/su14094916                  {'Pub. year': 2022.0, 'Citations': 0.0, 'Norm....
# 10.1108/et-11-2020-0341             {'Pub. year': 2022.0, 'Citations': 0.0, 'Norm....
# ...                                                                               ...
# 10.1080/0305569980240309            {'Pub. year': 1998.0, 'Citations': 10.0, 'Norm...
# 10.1111/1467-9752.00070             {'Pub. year': 1997.0, 'Citations': 55.0, 'Norm...
# 10.1111/j.1467-9752.1996.tb00406.x  {'Pub. year': 1996.0, 'Citations': 18.0, 'Norm...
# 10.1080/0305569940200208            {'Pub. year': 1994.0, 'Citations': 6.0, 'Norm....
# 10.1007/bf01383845                  {'Pub. year': 1993.0, 'Citations': 24.0, 'Norm...
#
# [173 rows x 9 columns]

# %%
sub_df_docs = df_docs.copy().reset_index()
sub_df_docs = sub_df_docs.merge(network_items.reset_index(), on="DOI", how="inner").dropna()

# %%
sub_df_docs["cluster"].value_counts()
# Out:
# 1    46
# 2    32
# 3    23
# 4    12
# 5     9
# 7     7
# 6     6
# 8     3
# Name: cluster, dtype: int64

# %%
from gensim import corpora
from gensim import models

# %%
df_docs_cluster = sub_df_docs[sub_df_docs["cluster"] == 2]
corpus = df_docs_cluster['doc_clean']
dictionary = corpora.Dictionary(corpus)

bow = [dictionary.doc2bow(text) for text in corpus]

tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]

# %%
from gensim.models import LsiModel
from gensim.models.coherencemodel import CoherenceModel

# %%
# %%time
for i in range(2, 16):
    lsi = LsiModel(corpus_tfidf, num_topics=i, id2word=dictionary)
    coherence_model = CoherenceModel(model=lsi, texts=df_docs_cluster['doc_clean'], dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    print('Coherence score with {} clusters: {}'.format(i, coherence_score))
# Out:
# Coherence score with 2 clusters: 0.3319961121253763
# Coherence score with 3 clusters: 0.44923320220030205
# Coherence score with 4 clusters: 0.5438725856291666
# Coherence score with 5 clusters: 0.5137276696813281
# Coherence score with 6 clusters: 0.4243115149140215
# Coherence score with 7 clusters: 0.4102539882875257
# Coherence score with 8 clusters: 0.4048022032647709
# Coherence score with 9 clusters: 0.4052681262048962
# Coherence score with 10 clusters: 0.41549891632588115
# Coherence score with 11 clusters: 0.4558606325447467
# Coherence score with 12 clusters: 0.4540632908284445
# Coherence score with 13 clusters: 0.4348391116833374
# Coherence score with 14 clusters: 0.43661209089236935
# Coherence score with 15 clusters: 0.4396292446741696
# Wall time: 45.7 s

# %%
num_topics = 5
lsi = LsiModel(corpus_tfidf, num_topics=num_topics, id2word=dictionary)

# %%
corpus_lsi = lsi[bow]
scores = [[] for _ in range(num_topics)]
for doc in corpus_lsi:
    for k in range(num_topics):
        scores[k].append(round(doc[k][1],2))

df_topic = df_docs_cluster.copy()
for k in range(num_topics):
    df_topic[f'score_topic_{k}'] = scores[k]

df_topic['Topic']= df_topic[[f'score_topic_{k}' for k in range(num_topics)]].apply(lambda x: x.argmax(), axis=1)
df_topic
# Out:
#                                 DOI  \
# 3          10.12973/eu-jer.11.2.965
# 314      10.1186/s40461-020-00108-6
# 341      10.1007/s42087-019-00080-y
# 343   10.1080/02619768.2019.1681965
# 345   10.1080/13636820.2019.1644364
# 346   10.1080/13636820.2019.1635634
# 348       10.1007/s10984-018-9276-y
# 349   10.1080/13573322.2017.1397507
# 369       10.1007/s10984-016-9209-6
# 371      10.1016/j.tate.2016.02.006
# 376      10.1016/j.tate.2015.04.007
# 382     10.6092/issn.1825-8670/5537
# 383     10.6092/issn.1825-8670/5572
# 386        10.1177/0734282914523913
# 389  10.1016/j.ijedudev.2013.11.003
# 392    10.1080/02602938.2012.680015
# 393    10.1080/13636820.2013.783612
# 400       10.1108/13665621311288485
# 402    10.1080/13540602.2012.746499
# 403    10.1080/13636820.2012.691536
# 408       10.1007/s10984-011-9092-0
# 415      10.1016/j.tate.2010.11.007
# 416       10.1007/s12564-010-9115-z
# 417       10.1080/00220271003759249
# 420       10.1108/03090591011049819
# 422       10.1007/s12186-009-9027-4
# 426       10.1080/13636820903194690
# 427       10.1080/13636820902904586
# 428       10.1080/13636820903194682
# 434       10.1080/13636820601145630
# 436       10.1080/13636820400200268
# 438         10.1111/1467-9752.00145
#
#                                                  Title  \
# 3    It is the Shared Aims, Trust and Compassion th...
# 314  How do teachers collaborate in Hungarian VET s...
# 341  How Do Students Describe Their Study Processes...
# 343  Powerful learning environments in secondary vo...
# 345  Does implementation of competence-based educat...
# 346  Evaluating competence-based vocational educati...
# 348  Competence and knowledge development in compet...
# 349  Helping students build competences in physical...
# 369  Design principles for hybrid learning configur...
# 371  Team learning and its association with the imp...
# 376  Teacher interpersonal behaviour and student mo...
# 382  Competence-based education to develop digital ...
# 383  eSchooling: An ICT-based approach to competenc...
# 386  Exploring the Validity and Robustness of a Com...
# 389  Perceived effects of competency-based training...
# 392  The relationship between perceived competence ...
# 393  Implementing Human Resources Management (HRM) ...
# 400  What makes teacher teams in a vocational educa...
# 402  Teaching in innovative vocational education in...
# 403  Can training teachers stimulate career learnin...
# 408  Development of student knowledge in competence...
# 415  Authentic and self-directed learning in vocati...
# 416  The role of schools' perceived human resource ...
# 417  Using an instrument to analyse competence-base...
# 420  Continuing professional development needs of t...
# 422  Aspects of competence-based education as footh...
# 426  What are vocational training conversations abo...
# 427  Teachers’ individual action theories about com...
# 428  Towards competence-based VET: Dealing with the...
# 434  The concept of competence in the development o...
# 436  Competence-based vet in the netherlands: Backg...
# 438  Where's the competence in competence-based edu...
#
#                                               Abstract  \
# 3    Teachers´ life-long learning and occupational ...
# 314  Background: This study investigates teacher co...
# 341  The competence-based approach has entered Finn...
# 343  Stakeholders in vocational education have diff...
# 345  Competence-based education (CBE) is an innovat...
# 346  This paper investigates the realisation of com...
# 348  Theory and research in the field of competence...
# 349  In the French education system, the current cu...
# 369  In today’s knowledge society, there is a deman...
# 371  Competence-based education (CBE) is the leadin...
# 376  Competence-based education requires changing t...
# 382  The competence approach to learning and teachi...
# 383  We present the eSchooling project, which aims ...
# 386  Research on the effectiveness of competence-ba...
# 389  The need to develop key competencies to meet t...
# 392  We explored how two types of study outcomes, p...
# 393  Vocational Education and Training (VET) Instit...
# 400  Purpose: At a time when secondary vocational e...
# 402  The orientation of vocational education toward...
# 403  In present-day society students are no longer ...
# 408  The purpose of this study was to gain insight ...
# 415  This article analyses the dilemmas and practic...
# 416  The change toward competence-based education h...
# 417  Competence-based education is becoming increas...
# 420  Purpose: The purpose of this article is to hel...
# 422  Recent developments in competence-based educat...
# 426  Research evidence shows that a career dialogue...
# 427  Dutch prevocational secondary schools are refo...
# 428  This article builds on a previous 2004 Journal...
# 434  This contribution follows the descriptive revi...
# 436  In the Dutch Vocational Education and Training...
# 438  This paper1 notes the apparent ineffectiveness...
#
#                                        Author Keywords  \
# 3    Co-passion; Dialogue; Professional identity; S...
# 314  Collegiality; Teacher collaboration; Teacher p...
# 341  Competence; Competence-based education; Narrat...
# 343  co-design; powerful learning environments; sha...
# 345  competence-based education (CBE); student sati...
# 346  agricultural schools; Competence-based educati...
# 348  Agriculture vocational education; Competence d...
# 349  competence; experience; Learning; physical edu...
# 369  Authentic learning; Educational design researc...
# 371  Competence-based education; Teacher teams; Tea...
# 376  Competence-based education; Indonesia; Intrins...
# 382  Authenticity; Digital competence; Integration ...
# 383  Competance-based education; Digital competence...
# 386  competence-based education; competency; higher...
# 389  Assessment; Competency-based training; Impleme...
# 392  deep approach to learning; earned credits; mot...
# 393  Human Resources Management; implementation pro...
# 400             Education; Team building; Team working
# 402  competence-based education; personal ideas and...
# 403  career learning; communication; intervention s...
# 408  Competence-based education; Concept mapping; K...
# 415  Authentic learning; Competence-based education...
# 416  Competence-Based Vocational Education; Continu...
# 417  Agricultural education; Competence-based educa...
# 420  Competence based training; Continuing professi...
# 422  Competence-based education; Connectivity; Life...
# 426  Communication; Competence-based education; Men...
# 427  Cognitive apprenticeship; Individual action th...
# 428  Competence; Competence-based education; Vet; V...
# 434
# 436
# 438
#
#                                         Index Keywords  \
# 3
# 314
# 341
# 343
# 345
# 346
# 348
# 349  conceptual framework; empiricism; human; human...
# 369
# 371
# 376
# 382
# 383
# 386
# 389  assessment method; educational development; im...
# 392
# 393
# 400
# 402
# 403
# 408
# 415
# 416
# 417
# 420
# 422
# 426
# 427
# 428
# 434
# 436
# 438
#
#                                                    doc  \
# 3    It is the Shared Aims, Trust and Compassion th...
# 314  How do teachers collaborate in Hungarian VET s...
# 341  How Do Students Describe Their Study Processes...
# 343  Powerful learning environments in secondary vo...
# 345  Does implementation of competence-based educat...
# 346  Evaluating competence-based vocational educati...
# 348  Competence and knowledge development in compet...
# 349  Helping students build competences in physical...
# 369  Design principles for hybrid learning configur...
# 371  Team learning and its association with the imp...
# 376  Teacher interpersonal behaviour and student mo...
# 382  Competence-based education to develop digital ...
# 383  eSchooling: An ICT-based approach to competenc...
# 386  Exploring the Validity and Robustness of a Com...
# 389  Perceived effects of competency-based training...
# 392  The relationship between perceived competence ...
# 393  Implementing Human Resources Management (HRM) ...
# 400  What makes teacher teams in a vocational educa...
# 402  Teaching in innovative vocational education in...
# 403  Can training teachers stimulate career learnin...
# 408  Development of student knowledge in competence...
# 415  Authentic and self-directed learning in vocati...
# 416  The role of schools' perceived human resource ...
# 417  Using an instrument to analyse competence-base...
# 420  Continuing professional development needs of t...
# 422  Aspects of competence-based education as footh...
# 426  What are vocational training conversations abo...
# 427  Teachers’ individual action theories about com...
# 428  Towards competence-based VET: Dealing with the...
# 434  The concept of competence in the development o...
# 436  Competence-based vet in the netherlands: Backg...
# 438  Where's the competence in competence-based edu...
#
#                                              doc_clean   id  \
# 3    [share, aim, trust, compass, allow, peopl, pro...   16
# 314  [teacher, collabor, hungarian, vet, school, qu...   47
# 341  [student, studi, process, compet, base, vocat,...  194
# 343  [power, learn, environ, secondari, vocat, educ...  210
# 345  [implement, compet, base, educ, mediat, impact...  236
# 346  [evalu, compet, base, vocat, educ, indonesia, ...  260
# 348  [compet, knowledg, develop, compet, base, voca...  286
# 349  [help, student, build, compet, physic, educ, t...  295
# 369  [design, principl, hybrid, learn, configur, in...  451
# 371  [team, learn, associ, implement, compet, base,...  466
# 376  [teacher, interperson, behaviour, student, mot...  501
# 382  [compet, base, educ, develop, digit, compet, c...  524
# 383  [eschool, ict, base, approach, compet, base, e...  528
# 386  [explor, valid, robust, compet, self, report, ...  570
# 389  [perceiv, effect, compet, base, train, acquisi...  581
# 392  [relationship, perceiv, compet, earn, credit, ...  602
# 393  [implement, human, resourc, manag, hrm, dutch,...  606
# 400  [make, teacher, team, vocat, educ, context, ef...  629
# 402  [teach, innov, vocat, educ, netherland, orient...  636
# 403  [train, teacher, stimul, career, learn, conver...  648
# 408  [develop, student, knowledg, compet, base, pre...  677
# 415  [authent, self, direct, learn, vocat, educ, ch...  688
# 416  [role, school, perceiv, human, resourc, polici...  690
# 417  [instrument, analys, compet, base, studi, prog...  699
# 420  [continu, profession, develop, need, teacher, ...  710
# 422  [aspect, compet, base, educ, foothold, improv,...  720
# 426  [vocat, train, convers, about, analysi, vocat,...  740
# 427  [teachers’, individu, action, theori, compet, ...  741
# 428  [compet, base, vet, deal, pitfal, articl, buil...  742
# 434  [concept, compet, develop, vocat, educ, train,...  771
# 436  [compet, base, vet, netherland, background, pi...  789
# 438  [where, compet, compet, base, educ, train, pap...  807
#
#                                 label  \
# 3                nissilä s.-p. (2022)
# 314                   bükki e. (2021)
# 341                 kepanen p. (2020)
# 343                 placklé i. (2020)
# 345  van griethuijsen r.a.l.f. (2020)
# 346                  misbah z. (2020)
# 348                  misbah z. (2019)
# 349                 escalié g. (2019)
# 369             cremers p.h.m. (2016)
# 371                  wijnia l. (2016)
# 376                  misbah z. (2015)
# 382               wesselink r. (2015)
# 383               ronchetti m. (2015)
# 386                khaled a.e. (2014)
# 389                  boahin p. (2014)
# 392             kamphorst j.c. (2013)
# 393                 runhaar p. (2013)
# 400             truijen k.j.p. (2013)
# 402               de bruijn e. (2012)
# 403                 winters a. (2012)
# 408                 koopman m. (2011)
# 415               de bruijn e. (2011)
# 416                 seezink a. (2011)
# 417              wesselink r. (2010a)
# 420                 seezink a. (2010)
# 422              wesselink r. (2010b)
# 426                 winters a. (2009)
# 427                 seezink a. (2009)
# 428                 biemans h. (2009)
# 434                  mulder m. (2007)
# 436                 biemans h. (2004)
# 438                     lum g. (1999)
#
#                                            description  ...       y  cluster  \
# 3    <table><tr><td>Authors:</td><td>nissilä s.-p.;...  ... -0.3984        2
# 314  <table><tr><td>Authors:</td><td>bükki e.; fehé...  ... -0.4060        2
# 341  <table><tr><td>Authors:</td><td>kepanen p.; mä...  ... -0.3204        2
# 343  <table><tr><td>Authors:</td><td>placklé i.; kö...  ... -0.3013        2
# 345  <table><tr><td>Authors:</td><td>van griethuijs...  ... -0.1211        2
# 346  <table><tr><td>Authors:</td><td>misbah z.; gul...  ... -0.2204        2
# 348  <table><tr><td>Authors:</td><td>misbah z.; gul...  ... -0.2820        2
# 349  <table><tr><td>Authors:</td><td>escalié g.; re...  ... -0.0504        2
# 369  <table><tr><td>Authors:</td><td>cremers p.h.m....  ... -0.0480        2
# 371  <table><tr><td>Authors:</td><td>wijnia l.; kun...  ... -0.1300        2
# 376  <table><tr><td>Authors:</td><td>misbah z.; gul...  ... -0.2302        2
# 382  <table><tr><td>Authors:</td><td>wesselink r.; ...  ... -0.2287        2
# 383  <table><tr><td>Authors:</td><td>ronchetti m.; ...  ... -0.3059        2
# 386  <table><tr><td>Authors:</td><td>khaled a.e.; g...  ... -0.3598        2
# 389  <table><tr><td>Authors:</td><td>boahin p.; hof...  ... -0.2927        2
# 392  <table><tr><td>Authors:</td><td>kamphorst j.c....  ... -0.1318        2
# 393  <table><tr><td>Authors:</td><td>runhaar p.; sa...  ... -0.2645        2
# 400  <table><tr><td>Authors:</td><td>truijen k.j.p....  ... -0.1677        2
# 402  <table><tr><td>Authors:</td><td>de bruijn e.</...  ... -0.3630        2
# 403  <table><tr><td>Authors:</td><td>winters a.; me...  ... -0.2470        2
# 408  <table><tr><td>Authors:</td><td>koopman m.; te...  ... -0.3081        2
# 415  <table><tr><td>Authors:</td><td>de bruijn e.; ...  ... -0.2808        2
# 416  <table><tr><td>Authors:</td><td>seezink a.; po...  ... -0.2618        2
# 417  <table><tr><td>Authors:</td><td>wesselink r.; ...  ... -0.0871        2
# 420  <table><tr><td>Authors:</td><td>seezink a.; po...  ... -0.2008        2
# 422  <table><tr><td>Authors:</td><td>wesselink r.; ...  ... -0.3264        2
# 426  <table><tr><td>Authors:</td><td>winters a.; me...  ... -0.2359        2
# 427  <table><tr><td>Authors:</td><td>seezink a.; po...  ... -0.2887        2
# 428  <table><tr><td>Authors:</td><td>biemans h.; we...  ... -0.2876        2
# 434  <table><tr><td>Authors:</td><td>mulder m.; wei...  ... -0.1563        2
# 436  <table><tr><td>Authors:</td><td>biemans h.; ni...  ... -0.2264        2
# 438  <table><tr><td>Authors:</td><td>lum g.</td></t...  ... -0.3340        2
#
#                                                weights  \
# 3    {'Links': 1.0, 'Citations': 0.0, 'Norm. citati...
# 314  {'Links': 1.0, 'Citations': 1.0, 'Norm. citati...
# 341  {'Links': 4.0, 'Citations': 0.0, 'Norm. citati...
# 343  {'Links': 1.0, 'Citations': 4.0, 'Norm. citati...
# 345  {'Links': 10.0, 'Citations': 5.0, 'Norm. citat...
# 346  {'Links': 5.0, 'Citations': 5.0, 'Norm. citati...
# 348  {'Links': 10.0, 'Citations': 4.0, 'Norm. citat...
# 349  {'Links': 1.0, 'Citations': 11.0, 'Norm. citat...
# 369  {'Links': 1.0, 'Citations': 20.0, 'Norm. citat...
# 371  {'Links': 10.0, 'Citations': 23.0, 'Norm. cita...
# 376  {'Links': 9.0, 'Citations': 34.0, 'Norm. citat...
# 382  {'Links': 5.0, 'Citations': 2.0, 'Norm. citati...
# 383  {'Links': 3.0, 'Citations': 3.0, 'Norm. citati...
# 386  {'Links': 3.0, 'Citations': 12.0, 'Norm. citat...
# 389  {'Links': 2.0, 'Citations': 25.0, 'Norm. citat...
# 392  {'Links': 1.0, 'Citations': 12.0, 'Norm. citat...
# 393  {'Links': 2.0, 'Citations': 15.0, 'Norm. citat...
# 400  {'Links': 2.0, 'Citations': 21.0, 'Norm. citat...
# 402  {'Links': 6.0, 'Citations': 30.0, 'Norm. citat...
# 403  {'Links': 2.0, 'Citations': 6.0, 'Norm. citati...
# 408  {'Links': 2.0, 'Citations': 12.0, 'Norm. citat...
# 415  {'Links': 9.0, 'Citations': 98.0, 'Norm. citat...
# 416  {'Links': 4.0, 'Citations': 11.0, 'Norm. citat...
# 417  {'Links': 14.0, 'Citations': 37.0, 'Norm. cita...
# 420  {'Links': 6.0, 'Citations': 15.0, 'Norm. citat...
# 422  {'Links': 5.0, 'Citations': 49.0, 'Norm. citat...
# 426  {'Links': 3.0, 'Citations': 29.0, 'Norm. citat...
# 427  {'Links': 2.0, 'Citations': 10.0, 'Norm. citat...
# 428  {'Links': 17.0, 'Citations': 75.0, 'Norm. cita...
# 434  {'Links': 9.0, 'Citations': 85.0, 'Norm. citat...
# 436  {'Links': 23.0, 'Citations': 169.0, 'Norm. cit...
# 438  {'Links': 1.0, 'Citations': 35.0, 'Norm. citat...
#
#                                                 scores score_topic_0  \
# 3    {'Pub. year': 2022.0, 'Citations': 0.0, 'Norm....         -4.77
# 314  {'Pub. year': 2021.0, 'Citations': 1.0, 'Norm....        -15.46
# 341  {'Pub. year': 2020.0, 'Citations': 0.0, 'Norm....         -4.40
# 343  {'Pub. year': 2020.0, 'Citations': 4.0, 'Norm....         -5.83
# 345  {'Pub. year': 2020.0, 'Citations': 5.0, 'Norm....        -11.58
# 346  {'Pub. year': 2020.0, 'Citations': 5.0, 'Norm....         -6.25
# 348  {'Pub. year': 2019.0, 'Citations': 4.0, 'Norm....         -6.11
# 349  {'Pub. year': 2019.0, 'Citations': 11.0, 'Norm...         -7.45
# 369  {'Pub. year': 2016.0, 'Citations': 20.0, 'Norm...         -6.19
# 371  {'Pub. year': 2016.0, 'Citations': 23.0, 'Norm...         -7.85
# 376  {'Pub. year': 2015.0, 'Citations': 34.0, 'Norm...         -5.73
# 382  {'Pub. year': 2015.0, 'Citations': 2.0, 'Norm....         -2.81
# 383  {'Pub. year': 2015.0, 'Citations': 3.0, 'Norm....         -2.17
# 386  {'Pub. year': 2014.0, 'Citations': 12.0, 'Norm...         -3.69
# 389  {'Pub. year': 2014.0, 'Citations': 25.0, 'Norm...         -4.15
# 392  {'Pub. year': 2013.0, 'Citations': 12.0, 'Norm...         -4.42
# 393  {'Pub. year': 2013.0, 'Citations': 15.0, 'Norm...         -6.05
# 400  {'Pub. year': 2013.0, 'Citations': 21.0, 'Norm...        -16.66
# 402  {'Pub. year': 2012.0, 'Citations': 30.0, 'Norm...         -5.52
# 403  {'Pub. year': 2012.0, 'Citations': 6.0, 'Norm....         -4.42
# 408  {'Pub. year': 2011.0, 'Citations': 12.0, 'Norm...         -3.48
# 415  {'Pub. year': 2011.0, 'Citations': 98.0, 'Norm...         -4.14
# 416  {'Pub. year': 2011.0, 'Citations': 11.0, 'Norm...         -8.94
# 417  {'Pub. year': 2010.0, 'Citations': 37.0, 'Norm...         -5.04
# 420  {'Pub. year': 2010.0, 'Citations': 15.0, 'Norm...         -9.90
# 422  {'Pub. year': 2010.0, 'Citations': 49.0, 'Norm...         -6.45
# 426  {'Pub. year': 2009.0, 'Citations': 29.0, 'Norm...         -3.76
# 427  {'Pub. year': 2009.0, 'Citations': 10.0, 'Norm...         -5.59
# 428  {'Pub. year': 2009.0, 'Citations': 75.0, 'Norm...         -5.22
# 434  {'Pub. year': 2007.0, 'Citations': 85.0, 'Norm...         -3.97
# 436  {'Pub. year': 2004.0, 'Citations': 169.0, 'Nor...         -4.60
# 438  {'Pub. year': 1999.0, 'Citations': 35.0, 'Norm...         -0.82
#
#     score_topic_1  score_topic_2  score_topic_3  score_topic_4  Topic
# 3            2.50          -1.86           0.43          -2.24      1
# 314          5.81           3.35          -4.73          -7.11      1
# 341          1.59          -0.27           1.40          -0.12      1
# 343          1.89          -3.27           1.01           3.45      4
# 345         -9.37          -0.48          -0.17          -0.11      4
# 346          0.44           2.10          -0.90           2.89      4
# 348          1.89           1.10          -0.21           4.31      4
# 349          3.76           1.09           2.80           0.83      1
# 369          3.39           0.18           1.05           5.46      4
# 371        -10.54          -1.06           1.41          -0.45      3
# 376         -0.64          -0.38          -2.09          -1.06      2
# 382          1.81           0.56           2.54           2.35      3
# 383          1.19          -0.86           1.92           0.58      3
# 386          1.54          -0.42           0.08           2.20      4
# 389         -0.27          -0.12           0.75          -1.31      3
# 392          1.60           0.08          -0.18           0.07      1
# 393          2.45           4.16          -1.49          -7.08      2
# 400        -16.62          -1.18           4.25          -1.69      3
# 402          2.87          -0.27           1.56          -2.24      1
# 403          2.53          -7.43          -0.18          -1.50      1
# 408          1.68           0.27           0.30           2.03      4
# 415          2.41          -1.08           1.30           0.42      1
# 416          5.61           5.90           2.16          -7.49      2
# 417          1.12          -0.32           1.29           3.88      4
# 420          4.99           4.35           6.36          -4.19      3
# 422          2.88          -1.73          -3.41           2.54      1
# 426          2.21          -7.20          -0.43          -1.53      1
# 427          3.15           2.05           4.76           0.87      3
# 428          0.38           1.13          -6.61           1.24      4
# 434          2.45           0.00          -0.24           3.68      4
# 436          2.16           1.43          -4.74          -0.16      1
# 438          0.47          -0.29           0.47           0.07      1
#
# [32 rows x 22 columns]

# %%
df_topic["Topic"].value_counts()
# Out:
# 1    12
# 4    10
# 3     7
# 2     3
# Name: Topic, dtype: int64

# %%
lsi.print_topics(num_topics)
# Out:
# [(0,
#   '-0.342*"team" + -0.216*"cbe" + -0.133*"pitfal" + -0.131*"vet" + -0.126*"polici" + -0.121*"teacher" + -0.120*"profession" + -0.118*"effect" + -0.102*"implement" + -0.099*"teach"'),
#  (1,
#   '-0.677*"team" + -0.244*"cbe" + -0.163*"effect" + -0.141*"satisfact" + 0.101*"polici" + 0.101*"profession" + -0.096*"associ" + 0.087*"career" + -0.086*"skill" + -0.085*"size"'),
#  (2,
#   '-0.436*"career" + -0.321*"convers" + -0.225*"mentor" + -0.217*"parti" + -0.211*"dialogu" + 0.190*"polici" + -0.150*"commun" + -0.128*"intervent" + -0.128*"employ" + -0.128*"shift"'),
#  (3,
#   '-0.452*"pitfal" + -0.269*"vet" + -0.169*"cbe" + -0.169*"2004" + 0.160*"digit" + 0.138*"team" + 0.136*"model" + 0.134*"action" + -0.123*"connect" + 0.121*"individu"'),
#  (4,
#   '-0.221*"polici" + -0.217*"hrm" + -0.185*"profession" + 0.162*"cbve" + 0.159*"programm" + 0.155*"design" + 0.146*"principl" + 0.139*"knowledg" + 0.135*"digit" + -0.135*"manag"')]

# %%
for ix in df_topic[df_topic["Topic"] == 1].index:
    row = df_topic.loc[ix]
    print(row["Title"],"\n")
# Out:
# It is the Shared Aims, Trust and Compassion that Allow People to Prosper: Teacher Educators´ Lifelong Learning in Competence-based Education
#
# How do teachers collaborate in Hungarian VET schools? A quantitative study of forms, perceptions of impact and related individual and organisational factors
#
# How Do Students Describe Their Study Processes in the Competence-Based Vocational Special Education Teacher Training?
#
# Helping students build competences in physical education: theoretical proposals and illustrations
#
# The relationship between perceived competence and earned credits in competence-based higher education
#
# Teaching in innovative vocational education in the Netherlands
#
# Can training teachers stimulate career learning conversations? Analysis of vocational training conversations in Dutch secondary vocational education
#
# Authentic and self-directed learning in vocational education: Challenges to vocational educators
#
# Aspects of competence-based education as footholds to improve the connectivity between learning in school and in the workplace
#
# What are vocational training conversations about? Analysis of vocational training conversations in dutch vocational education from a career learning perspective
#
# Competence-based vet in the netherlands: Background and pitfalls
#
# Where's the competence in competence-based education and training?
